# %%
from data_generator.n_body import NBody

# %%
import numpy as np

# %%
rng = np.random.default_rng(48)

# %%
masses = rng.random(5)
masses
# Out:
# array([0.38769987, 0.59577349, 0.51380055, 0.6944919 , 0.65249675])

# %%
nb = NBody(1, masses)

# %%
training = nb.generate_random_observations(1000, rng, 1, 0.1)
training
# Out:
#            x1        y1        z1        x2        y2        z2        x3  \
# 0    0.750049  0.273878  0.111778  0.634957 -0.606572 -0.821857 -0.867467
# 1   -0.894433  0.558972  0.352128 -0.150240 -0.145248  0.331195  0.728066
# 2    0.846421  0.761525 -0.233039 -0.887265  0.193159  0.169365 -0.416858
# 3   -0.283671  1.012954  0.202399  1.004687  0.933896  0.542616 -0.988654
# 4   -0.859322  0.281220  0.171424 -0.809554  0.569537 -0.542711 -0.058851
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.216221  0.172998  0.134014 -0.557810  0.901558 -0.950095 -0.846850
# 996 -0.075073 -0.364009  0.359268  0.878149 -0.369910 -0.156539 -0.784897
# 997  0.956131 -0.832522 -0.785379  0.955591 -0.582865 -0.515818  1.052982
# 998 -0.591082 -0.209374  0.143164 -0.902932 -0.178658 -0.892332  0.929248
# 999 -0.333891  0.646196  0.429782  0.976986 -0.988926 -0.679556 -0.964224
#
#            y3        z3        x4        y4        z4        x5        y5  \
# ...

# %%
test = nb.generate_random_observations(1000, rng, 1, 0.1)
test.columns
test = test.drop('forces', axis=1)
test
# Out:
#            x1        y1        z1        x2        y2        z2        x3  \
# 0    0.269228 -0.828892 -0.681068 -0.204016  0.144955 -0.175682  0.876675
# 1   -0.014879  0.471292 -0.115568 -0.108882 -0.775057  0.890757 -0.505782
# 2   -0.786870  0.600572 -0.739953 -0.052499  0.346888  0.751718 -0.134873
# 3    0.424292  0.643285 -0.128353 -0.802702  0.217647 -0.245173  0.383198
# 4    0.666517  0.308779  0.368925  0.074911 -0.271695  0.345379  0.578341
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.970480  0.489863  0.280224  0.842181 -0.046070 -0.819416 -0.451084
# 996  0.194209 -0.350238 -0.651333 -0.828692  0.010932 -0.238719  0.852795
# 997 -0.008262  0.732487  0.270051 -0.294338 -0.369125 -0.642865 -0.961998
# 998 -0.859528  0.267409 -0.362073 -0.884499 -0.346407 -0.722198 -0.787348
# 999  0.329551  0.124568 -0.253752  0.087880 -0.736171 -0.359807  0.273100
#
#            y3        z3        x4        y4        z4        x5        y5  \
# ...
